# %%
from PIL import Image
import sys
sys.path.append("../tools")
# from utils import convert_to_jpg
import albumentations as A
import numpy as np

# %%
ds = load_from_disk(dataset_path="../../data/big/train")

# %%
img = Image.open("../../tmp/cat.png").convert("RGB")

# %%
img
# Out:
# <PIL.Image.Image image mode=RGB size=1050x750>

# %%
def to_jpg(img: Image, q: int):
    t = A.ImageCompression(quality_lower=q,quality_upper=q,p=1)
    return Image.fromarray(t(image=np.asarray(img))["image"])

# %%
img_jpg_40 = to_jpg(img,40)
img_jpg_10 = to_jpg(img,10)

# %%
img_jpg_40
# Out:
# <PIL.Image.Image image mode=RGB size=1050x750>

# %%
img_jpg_10
# Out:
# <PIL.Image.Image image mode=RGB size=1050x750>

# %%
ds_jpeg = load_from_disk("../../data/big_QF_40/train")

# %%
import matplotlib.pyplot as plt
import time
from IPython.display import clear_output

for e in ds_jpeg:
    print("Real" if e["label"] == 1 else "Fake")
    display(e["image"])
    time.sleep(.5)
    clear_output(wait=True)
# Out:
# Real
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=240x160>
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[22], line 8
#       6 print("Real" if e["label"] == 1 else "Fake")
#       7 display(e["image"])
# ----> 8 time.sleep(.5)
#       9 clear_output(wait=True)
#
# KeyboardInterrupt:
